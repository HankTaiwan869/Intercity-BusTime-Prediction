# %%
import polars as pl
from constants import DATA_FOLDER

# %%
df = pl.read_csv(DATA_FOLDER / "youbike.csv")

# %%
df.select(pl.col("StationUID").n_unique())
# Out:
# shape: (1, 1)
# ┌────────────┐
# │ StationUID │
# │ ---        │
# │ u32        │
# ╞════════════╡
# │ 644        │
# └────────────┘
