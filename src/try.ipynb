# %%
import holidays

# %%
tw_holidays = holidays.country_holidays(country="Taiwan", language="zh_TW")

for date, name in sorted(tw_holidays(years=2026).items()):
    print(f"{date}: {name}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 tw_holidays = holidays.country_holidays(country="Taiwan", language="zh_TW")
# ----> 3 for date, name in sorted(tw_holidays(years=2026).items()):
#       4     print(f"{date}: {name}")
#
# TypeError: 'Taiwan' object is not callable
