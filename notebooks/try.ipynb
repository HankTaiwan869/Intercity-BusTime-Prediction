# %%
# to import from local modules
from pathlib import Path
import sys  

parent_dir = str(Path().resolve().parents[0])
sys.path.insert(0, parent_dir)

# %%
import polars as pl
from src.constants import DATA_FILE, SAMPLE

# %%
df = pl.scan_parquet(DATA_FILE)

# %%
df.head().collect()
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.head().collect()
#
# File c:\Users\stat_835\python\Intercity-BusTime-Prediction\.venv\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File c:\Users\stat_835\python\Intercity-BusTime-Prediction\.venv\Lib\site-packages\polars\lazyframe\opt_flags.py:326, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     323         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     325 kwargs["optimizations"] = optflags
# --> 326 return function(*args, **kwargs)
#
# ...
